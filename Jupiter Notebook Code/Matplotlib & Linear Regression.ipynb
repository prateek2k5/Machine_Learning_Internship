# %%
#Ploting a Line Grapgh

import matplotlib.pyplot as plt
x=[5,2,7]
y=[2,16,4]
plt.plot(x,y)
plt.title('Info')
plt.ylabel('Y axis')
plt.xlabel('X axis')
plt.show()

# %%
#Bar Graph
x=[0.25,1.25,2.25,3.25,4.25]
y=[50,40,70,80,20]
plt.bar(x,y,label="BMW",color='g',width=0.5)
i=[.75,1.75,2.75,3.75,4.75]
j=[80,20,20,50,60]
plt.bar(i,j,label='Audi',color='r',width=0.5)
plt.legend()
plt.xlabel('Days')
plt.ylabel('Kms')
plt.title('Information')
plt.show()

# %%
#Linear Regression 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_excel('Uni_Data.xlsx')
data
x=data[['Input']]
y=data[['Output']]
plt.plot(x,y,'ro')
plt.xlabel('Input_Hours')
plt.ylabel('Output_Score')
# Out:
# Text(0, 0.5, 'Output_Score')

# %%
from sklearn.model_selection import train_test_split
#Function used to split the data between training data and testing data
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42) #test_size=0.3 mean 30% data for testing
print(xtrain,ytrain)
# Out:
#     Input
# 22    3.8
# 5     1.5
# 2     3.2
# 12    4.5
# 15    8.9
# 3     8.5
# 4     3.5
# 20    2.7
# 17    1.9
# 21    4.8
# 18    6.1
# 24    7.8
# 7     5.5
# 10    7.7
# 14    1.1
# 19    7.4
# 6     9.2     Output
# 22      35
# 5       20
# 2       27
# 12      41
# 15      95
# 3       75
# 4       30
# 20      30
# 17      24
# 21      54
# 18      67
# 24      86
# 7       60
# 10      85
# 14      17
# 19      69
# 6       88

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)

#Model Testing
yp=lr.predict(xtest)
plt.plot(xtest,yp,color='green')
plt.scatter(xtest,ytest)

# %%
from sklearn import metrics
Mae=metrics.mean_absolute_error(ytest,yp)
MSE=metrics.mean_squared_error(ytest,yp)
RMSE=np.sqrt(MSE)
print("MAE",Mae,"MSE",MSE,"RMSE",R)
# Out:
# MAE 4.499999999999998 MSE 23.61945761415174 RMSE 4.859985351228103

# %%
hours1=np.array([8,4.5,6.2,3.6])
hourdf=pd.DataFrame(hours1)
print(hourdf)
print()
yp1=lr.predict(hourdf)
print(hourdf,yp1)
# Out:
#      0
# 0  8.0
# 1  4.5
# 2  6.2
# 3  3.6
#
#      0
# 0  8.0
# 1  4.5
# 2  6.2
# 3  3.6 [[80.47852417]
#  [46.49163089]
#  [62.99955048]
#  [37.75214405]]
# C:\Users\Prateek Verma\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
in_hour=float(input("Enter the number of hours studied : "))
indf=pd.DataFrame([[in_hour]])
indf.columns=["Input"]
print(indf)
yp=lr.predict(indf)
print("Your Predicted Marks are : ",yp)
# Out:
# Enter the number of hours studied :  8
#    Input
# 0    8.0
# Your Predicted Marks are :  [[80.47852417]]

# %%
#Example 2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv('salary_data.csv')
data
x=data[['YearsExperience']]
y=data[['Salary']]
plt.plot(x,y,'ro')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %%
from sklearn.model_selection import train_test_split
#Function used to split the data between training data and testing data
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=42) #test_size=0.3 mean 30% data for testing
print(xtrain,ytrain)
# Out:
#     YearsExperience
# 0               1.1
# 4               2.2
# 16              5.1
# 5               2.9
# 13              4.1
# 11              4.0
# 22              7.9
# 1               1.3
# 2               1.5
# 25              9.0
# 3               2.0
# 21              7.1
# 26              9.5
# 18              5.9
# 29             10.5
# 20              6.8
# 7               3.2
# 10              3.9
# 14              4.5
# 19              6.0
# 6               3.0     Salary
# 0    39343
# 4    39891
# 16   66029
# 5    56642
# 13   57081
# 11   55794
# 22  101302
# 1    46205
# 2    37731
# 25  105582
# 3    43525
# 21   98273
# 26  116969
# 18   81363
# 29  121872
# 20   91738
# 7    54445
# 10   63218
# 14   61111
# 19   93940
# 6    60150

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(xtrain,ytrain)

#Model Testing
yp=lr.predict(xtest)
plt.plot(xtest,yp,color='green')
plt.scatter(xtest,ytest)

# %%
from sklearn import metrics
Mae=metrics.mean_absolute_error(ytest,yp)
MSE=metrics.mean_squared_error(ytest,yp)
RMSE=np.sqrt(MSE) #Cost Function
print("MAE",Mae,"MSE",MSE,"RMSE",RMSE)
# Out:
# MAE 5161.328710400186 MSE 37784662.46621317 RMSE 6146.923007994583

# %%
in_hour=float(input("Enter the years of Experience : "))
indf=pd.DataFrame([[in_hour]])
indf.columns=["YearsExperience"]
print(indf)
yp=lr.predict(indf)
print("Your Predicted Salary is : ",yp)
# Out:
# Enter the years of Experience :  5
#    YearsExperience
# 0              5.0
# Your Predicted Salary is :  [[72613.84695397]]
